# %% [markdown]
# # PSTAT 100 Project report

# %% [markdown]
# # Exploring the relationship between COVID-19 death rates and vaccination rates in the United States from 2021 to 2022
#
# Pippa Lin, Joshua Price, Justin Pak, Minsheng Ye
#
# #### Author contributions
#
# Pippa Lin worked on tidying the dataset and exploratory analysis on Stage 1. On Stage 2 Pippa Lin made plots for the first question, also wrote caption and results for those plots. Pippa also worked on analysis of Question 1.
#
# Joshua Price explored the tidied data and showed basic properties of the dataset on Stage 1. On Stage 2 Joshua Price made plots for the second question, also wrote caption and results for those plots. Joshua also worked on analysis of Question 2.
#
# Justin Pak worked on the data documentation and prepared the data description on Stage 1. Justin Pak wrote the Methods, Results, and Dicussion on Stage 2.
#
# Minsheng Ye studied the background information and prepared the introduction on Stage 1. And wrote the Abstract, Background, Datasets, and Aims on Stage 2.
# #### Abstract
#
# We are going to investigate the relationship between COVID-19 death rates, multiple dose rate, and vaccination rates in the United States from 2021 to 2022. We used linear regression to see if the death rate varies with the vaccination rate. First, we will explore any relationship between vaccination rate and death rate of the states. Second, we will explore the relationship between the multiple dose rate and the death rate. After using some scatter plot based on linear regression, we found out there is no relationship between the vaccination rate and death rate. Then we try to use linear model to explore the relationship between those two variables, and we confirmed that there is no relationship between the vaccination rate and death rate. And we found out there is a weak relationship between death rate and multiple dose rate, but we believed the linear regression model should not be used to predict death rates. Although there are no relationship between COVID-19 death rates, multiple dose rate, and vaccination rates, we believe there might be some relationship if we use another statistical analysis.

# %% [markdown]
# ---
# ## Introduction
#
# In this project, we are going to investigate the relationship between COVID-19 death rates and vaccination rates in the United States from 2021 to 2022. We will base our study on the following questions: a) Is there a relationship between vaccination rates and mortality in each state? b) Is there a relationship between vaccination rates for more than one dose and mortality?
#
# ### Background
#
# With its widespread disease, fatalities, and severe social and economic disruption, the COVID-19 pandemic has profoundly influenced the whole world. The epidemic has significantly impacted the USA’s public health and economy, resulting in numerous job losses, company closures, and personal financial suffering.
#
# In this study, we want to investigate the connection between the pandemic's mortality and vaccination rates. The death rate can proxy for the percentage of COVID-19-infected individuals who have passed away over time. The percentage of the population who has received an anti-virus vaccine can be determined via vaccination rates. The death and immunization rates may alter in the future due to the realization that the pandemic is a continuing and changing issue. Hence, we choose the American statistics from 2021 to 2022.
#
# We will utilize openly available data from the Centers for Disease Control and Prevention (CDC) to examine these variables. Also, we will model the connection between the death rate and vaccination rates in the US using statistical analysis (i.e. Linear Regression). Finally, we will look at potential variations in mortality and immunization rates throughout the nation's regions.
#
# This project aims to comprehend the pandemic's effects on the US during 2021 and 2022. Furthermore, we wish to apply linear regression to examine the link between death and vaccination rates to determine if future death rate would decline as vaccination rates rose.
#
# ### Aims
#
# Our aims of this project were to explore two questions based on vaccination rate and death rate in the United States from 2021 to 2022. Our first question was to explore the relationship between vaccination rate and death rate of the states, and our second question was to explore the relationship between the more-than-one-dose rate and the death rate. To approach our first question, we used vaccination_rate and death_rate to be our variables and create the visualization for this project. To calculate the vaccination_rate, we used the numbers of people vaccinated in the United States divided by the numbers of total vaccines distributed in 2021 and 2022. We made some different plots to show the relationship between death rate and vaccination rate. Then we found that there was no significant linear relationship between vaccination rate and death rate. We decided to use linear model to confirm it. In the linear model, we found that the estimated coefficient is close to 0, and the $R^2$ is neagtive. Therefore, we confirm that there is no linear relaitionship between vaccination rate and death rate in 2021 and 2021. To approach our second question, we used multiple_dose_rate and death_rate to be our variables and create the visualization for this project. Then we still found out there was no significant linear relationship between multiple dose rate and death rate.

# %% [markdown]
# ---
# ## Materials and methods
#
# ### Datasets
#
# Both datasets are of csv type data and will be merged into 2 bigger datasets (2021 dataset and 2022 dataset) for further analysis. For this project, we will be working with variables year, month, state, new_cases, new_deaths, total_vaccination, total_distriubted, people_vaccinated. The years we are working with is between 2021 and 2022 because that is when vaccinations became public.
#
# Name | Variable description | Type | Units of measurement
# ---|---|---|---
# year | Year that the data was collected | Numeric | Years
# month | Month that the data was collected | Numeric | Months (1 -12), 1 being January and increasing by month
# state | The territory that the data was collected in | Character string | Federal state
# new_cases | New cases each month | Numeric | one person infected
# new_deaths | New deaths each month | Numeric | one person's death
# total_vaccination | Total vaccination each month including both 1st dose and 2nd dose | Numeric | dose
# total_distributed | Counts of COVID vaccines shipped to the states in that month through CDC's Vaccine Tracking System | Numeric | dose
# people_vaccinated | Total number of people who received at least one vaccine dose in that month | Numeric | dose
# vaccination_rate | The proportion of vaccination | Numeric | Percentage
# death_rate | The proportion of death | Numeric | Percentage

# %% [markdown]
# **Notice**: after our data tidying, we only have Alabama, Alaska, Arizona, Arkansas, Colorado,Connecticut, Delaware, District of Columbia, Florida, Georgia, Guam, Hawaii, Indiana, Iowa, Kentucky, Louisiana, Maine, Maryland, Massachusetts, Michigan,Minnesota, Mississippi, Missouri, Montana, Nebraska, New Jersey, New Mexico, North Carolina, North Dakota, Ohio, Oklahoma, Oregon, Rhode Island, South Carolina, South Dakota, Tennessee, Utah, Vermont, Virginia, Washington, West Virginia, and Wisconsin.
# Therefore, when we say in most regions in the U.S., these states are what we included, and it is the sampling frame of our study.

# %% [markdown]
# **Example lines for data in 2021:**
# <br>
#
# ![%E6%88%AA%E5%B1%8F2023-03-22%20%E4%B8%8B%E5%8D%888.16.08.png](attachment:%E6%88%AA%E5%B1%8F2023-03-22%20%E4%B8%8B%E5%8D%888.16.08.png)

# %% [markdown]
# **Example lines for data in 2022:**
# <br>
#
# ![%E6%88%AA%E5%B1%8F2023-03-22%20%E4%B8%8B%E5%8D%888.16.21.png](attachment:%E6%88%AA%E5%B1%8F2023-03-22%20%E4%B8%8B%E5%8D%888.16.21.png)

# %% [markdown]
# ### Methods
#
# Since each state has a different population, the only reasonable variable we can use is the rate. Therefore, we did not need to use PCA to select the variables. Also, the only model we learned for PSTAT100 was the lienar model, so our main goal was to understand `a) whether there was a lienar relationship between death rate and vaccination rate` and `b) whether there was a lienar relationship between death rate and multiple-dose rate.`
#
# To address the frist question, we built a linear model with vacciantion rate as the explonatory variable and death rate as the response variable. We generate coefficient tables and their standard deviation, and calcualted R square in order to make our conlusion.
#
# To address the second question, we frist calculated the multiple-dose rate by creating a new column called `multiple_dose_rate` by using (`total_vaccinations` - `people_vaccinated`)/`peoppel_vaccinated`. After that, we repeat the same process as the first question and came up with the conclusion.

# %% [markdown]
# ---
# ## Results

# %% [markdown]
# ## Question 1: Is there a linear relationship between vaccination rate and death rate of the states?

# %% [markdown]
# ### Vaccination rate versus Death rate 2021:
# ![visualization.png](attachment:visualization.png)

# %% [markdown]
# ### Vaccination rate versus Death rate 2022:
# ![visualization.png](attachment:visualization.png)

# %% [markdown]
# From the two plots, we can see that there is nearly no linear relationship between the two variables. However, it seems to look a bit changed from the 2021 plot. But we still cannot etermine whether the death rate varied with vaccination rate.
#
# To confirm our conjecture，we need to make the further investigate. We built a linear model for 2021 and 2022 to confirm that there is indeed no linear relationship. After fitting the linear model to both 2021 and 2022, we can get our result from the coefficient estimation, coefficient estimation's standard error, and $R^2$.

# %% [markdown]
# <br>
#
# ### Coefficient table for vaccination rate in 2021

# %% [markdown]
# ![%E6%88%AA%E5%B1%8F2023-03-22%20%E4%B8%8B%E5%8D%889.24.36.png](attachment:%E6%88%AA%E5%B1%8F2023-03-22%20%E4%B8%8B%E5%8D%889.24.36.png)

# %% [markdown]
# Both coefficient estimates of the vaccination rate is extremely small, nearly zero. Therefore, we can say that there actually isn't any linear relationship between vaccination rate and death rate. Furthermore, when we calculate the $R^2$ value, we got -0.8816. The reason for the $R^2$ is negative value is only when the chosen model does not follow the trend of the data. **In conclusion, there is no linear relationship between vaccination rate and death rate in 2021 in most U.S regions**.

# %% [markdown]
# <br>
#
# ### Coefficient table for vaccination rate in 2022

# %% [markdown]
# ![%E6%88%AA%E5%B1%8F2023-03-22%20%E4%B8%8B%E5%8D%889.31.35.png](attachment:%E6%88%AA%E5%B1%8F2023-03-22%20%E4%B8%8B%E5%8D%889.31.35.png)

# %% [markdown]
# Similar to 2021, both coefficient estimates of the vaccination rate is extremely small, nearly zero. Therefore, we can say that there actually isn't any linear relationship between vaccination rate and death rate. Furthermore, when we calculate the $R^2$ value, we got -0.5591. The reason for the $R^2$ is negative value is only when the chosen model does not follow the trend of the data. **In conclusion, there is no linear relationship between vaccination rate and death rate in 2021 in most U.S regions**.

# %% [markdown]
# ### Conclusion
# Overall, in both 2021 and 2022, the estimated intercept are both 0, and the estimated slope is 5.6389e-311 and 1.7584e-312. The $R^2$ values are -0.8816 for 2021 and -0.5591 for 2022. Since our linear regression $R^2$ values are negative and coefficients are close to 0 for both datasets, we can confirm no linear relationship between vaccination rates and death rates in most of the United States regions in 2021 and 2022.

# %% [markdown]
# ## Question 2: Is there a relationship between multiple-vaccination rate and death rate of the states?

# %% [markdown]
# Since there is no linear relationship between vaccination rate and death rate, we want to further explore whether multiple-dose rate has such relationship with death during the pandemic.

# %% [markdown]
# ### Multiple-dose rate versus Death rate 2021:
# ![visualization.png](attachment:visualization.png)

# %% [markdown]
# As we can see from the scatter plots, they look very similar to the earlier exploration of a relationship between the first dose of the vaccine and death rates. There appears to be no distinct pattern of a linear relationship.

# %% [markdown]
# ### Multiple-dose rate versus Death rate 2022:
# ![visualization%20%281%29.png](attachment:visualization%20%281%29.png)

# %% [markdown]
# As we can see from the scatter plots, we can see that these points are distributed more spreadly, but we still cannot determine whether the death rate varied with multiple dose rate.

# %% [markdown]
# After following a similar procedure (i.e., fitting a linear regression model into the datasets for 2021 and 2022), we can get a better-fitting model than our previous question.

# %% [markdown]
# ### Coefficient table for multiple dose rate in 2021

# %% [markdown]
# ![%E6%88%AA%E5%B1%8F2023-03-22%20%E4%B8%8B%E5%8D%8811.24.40.png](attachment:%E6%88%AA%E5%B1%8F2023-03-22%20%E4%B8%8B%E5%8D%8811.24.40.png)

# %% [markdown]
# We can see that the estimated intercept is 0.0165 and slope is 0.000018, which are still close to 0 but better than our first model. However, after taking standard error into account, we can see that 0 is included in the slope estimation. And when we calculate the $R^2$ value, we got 0.0000016. Since the $R^2$  value is near 0, it suggests that multiple dose rate does not predict the death rate in most U.S states well in 2021.

# %% [markdown]
# ### Coefficient table for multiple dose rate in 2022

# %% [markdown]
# ![%E6%88%AA%E5%B1%8F2023-03-22%20%E4%B8%8B%E5%8D%8811.27.23.png](attachment:%E6%88%AA%E5%B1%8F2023-03-22%20%E4%B8%8B%E5%8D%8811.27.23.png)

# %% [markdown]
# Similar to what we observed in 2021. We can see that the estimated intercept is 0.012174 and slope is -0.000255, which are also close to 0. Also, 0 is included in the estimation after adding standard error. When we calculate the $R^2$ value, we got 0.004. Since the $R^2$  value is near 0, it suggests that multiple dose rate does not predict the death rate in most U.S states well in 2022.

# %% [markdown]
# ### Conclusion
# Overall, in both 2021 and 2022, the estimated intercept are both 0, and the estimated slope are also close to zero, indicating that fitting a linear model for multi-dose rate and death rate will not have significant parameters. Moreover, the near-zero $R^2$ shows that the proportion of variation in the death rate only has extremely small proportion explained by the linear model. In short, the conclusion from the second question is still: **there is no linear relationship between multi-does rate and death rate for most U.S. states in both 2021 and 2022**.

# %% [markdown]
# ---
# ## Discussion
#
# Our initial expectation was that there would be a negative linear relationship between mortality and vaccination rates. However, in 2021 and 2022, there is no linear relationship between mortality and single/multiple vaccination rates. Limitations include data collection and collation, variable selection, and model selection.
#
# Data collection issues are probably the least likely to lead to poor model fit. However, the most important constraint in this category is that we need to know how the data in the vaccination dataset was collected. We presume that it was scraped through surveys and the web. If the data were collected through surveys, then the people who answered the surveys are biased and there is no definitive way to prove whether the subjects are telling the truth. In this case, people have reasons to lie about vaccination status, such as not wanting to be vaccinated, but appearing to do so to avoid conflict. If data are obtained through web scraping, it is likely that data will be lost or inconsistent. Large-scale web scraping, such as vaccination status for all countries, can also run slowly, which may mean taking shortcuts to reduce the time it takes to scrape data.
#
# Collation problems may be an important factor in the poor fit of our linear regression model. Since we merged two datasets, the first for COVID cases and deaths and the second for vaccinations, there may have been a loss of data due to insufficient cleaning and standardization of the data prior to merging. Vaccination rates appear to be cumulative in the merged dataset, so we attempted to make them monthly. In the collation, there may have been an error in counting rather than accumulating, or we may have misjudged the cumulative vaccination rates. However, this is very unlikely. It is also possible that human error in the calculations contributed to these models. In addition, variable selection may have been a limiting factor, as all rates were aggregated rather than from the original source. As a result, negative vaccination rates emerged that should not have been present.
#
# A final possible limitation is that the linear regression model is not appropriate for our data set. Although linear regression performs well for predicting one-to-one relationships between the different values in this case, it is sensitive to outliers and noise. In such a complex analysis of a polarizing measure to prevent COVID-19, there would be outliers and other variables in mortality. This was especially true in the years when vaccines were first introduced to the public. Another drawback of linear regression is the assumption of linearity between the dependent and independent variables. As we can see from the graphs, there does not appear to be a linear relationship between both cases and years.
#
# Nonetheless, the model fit is correct and these variables are not correlated. We know that the main goal of the vaccine is to prevent patients from being infected, which should mitigate the increase in mortality. Although a small reduction in severity has been claimed, there does not seem to be a definitive study on the reduction of the risk of death from COVID-19 infection. Another step that could complement this study would be to see if there is a linear relationship between vaccination rates and case rates. If we could find a linear relationship between these variables, this would likely mean that there should be a relationship between the vaccine and COVID-19 mortality, since it is not possible to die from COVID-19 without first contracting the virus.
#
# Finally, it is worth noting that the data are for 2021 and 2022 only. The vaccine is first introduced to the public in 2021 and is not available to all age groups until 2022. This means that we will only know the true efficacy of the vaccine after more time has passed. Time constraints prevent us from seeing the full picture, including our study and other studies on COVID-19. Also, after dropping states with lots of missing datas, our conclusion is limited to the states included in our sample.
#
# To improve our study, we need to look for more reliable data and get access to a complete data information. Moreover, we can look for more dataset and merge potential variables to create a more comprehensive dataset. When dealing with missing data, we need to learn more method such as impute it from the other rows, instead of dropping them directly. Last but not least, model selection is also essential. When we fail to see a significant linear trend, we can consider fitting more advanced model and see our result.

# %% [markdown]
# ---
# ## Discussion
#
# Our initial expectation was that there would be a negative linear relationship between mortality and vaccination rates. However, in 2021 and 2022, there is no linear relationship between mortality and single/multiple vaccination rates. Limitations include data collection and collation, variable selection, and model selection.
#
# Data collection issues are probably the least likely to lead to poor model fit. However, the most important constraint in this category is that we need to know how the data in the vaccination dataset was collected. We presume that it was scraped through surveys and the web. If the data were collected through surveys, then the people who answered the surveys are biased and there is no definitive way to prove whether the subjects are telling the truth. In this case, people have reasons to lie about vaccination status, such as not wanting to be vaccinated, but appearing to do so to avoid conflict. If data are obtained through web scraping, it is likely that data will be lost or inconsistent. Large-scale web scraping, such as vaccination status for all countries, can also run slowly, which may mean taking shortcuts to reduce the time it takes to scrape data.
#
# Collation problems may be an important factor in the poor fit of our linear regression model. Since we merged two datasets, the first for COVID cases and deaths and the second for vaccinations, there may have been a loss of data due to insufficient cleaning and standardization of the data prior to merging. Vaccination rates appear to be cumulative in the merged dataset, so we attempted to make them monthly. In the collation, there may have been an error in counting rather than accumulating, or we may have misjudged the cumulative vaccination rates. However, this is very unlikely. It is also possible that human error in the calculations contributed to these models. In addition, variable selection may have been a limiting factor, as all rates were aggregated rather than from the original source. As a result, negative vaccination rates emerged that should not have been present.
#
# A final possible limitation is that the linear regression model is not appropriate for our data set. Although linear regression performs well for predicting one-to-one relationships between the different values in this case, it is sensitive to outliers and noise. In such a complex analysis of a polarizing measure to prevent COVID-19, there would be outliers and other variables in mortality. This was especially true in the years when vaccines were first introduced to the public. Another drawback of linear regression is the assumption of linearity between the dependent and independent variables. As we can see from the graphs, there does not appear to be a linear relationship between both cases and years.
#
# Nonetheless, the model fit is correct and these variables are not correlated. We know that the main goal of the vaccine is to prevent patients from being infected, which should mitigate the increase in mortality. Although a small reduction in severity has been claimed, there does not seem to be a definitive study on the reduction of the risk of death from COVID-19 infection. Another step that could complement this study would be to see if there is a linear relationship between vaccination rates and case rates. If we could find a linear relationship between these variables, this would likely mean that there should be a relationship between the vaccine and COVID-19 mortality, since it is not possible to die from COVID-19 without first contracting the virus.
#
# Finally, it is worth noting that the data are for 2021 and 2022 only. The vaccine is first introduced to the public in 2021 and is not available to all age groups until 2022. This means that we will only know the true efficacy of the vaccine after more time has passed. Time constraints prevent us from seeing the full picture, including our study and other studies on COVID-19. Also, after dropping states with lots of missing datas, our conclusion is limited to the states included in our sample.
#
# To improve our study, we need to look for more reliable data and get access to a complete data information. Moreover, we can look for more dataset and merge potential variables to create a more comprehensive dataset. When dealing with missing data, we need to learn more method such as impute it from the other rows, instead of dropping them directly. Last but not least, model selection is also essential. When we fail to see a significant linear trend, we can consider fitting more advanced model and see our result.

# %% [markdown]
# ---
# ## Conclusion
#
# In this project, we aimed to study the relationship between vaccination rates, multi-dose vaccination rates and mortality in the U.S. from 2021 to 2022. We collected data from two sources and organized the data so that they were recorded on a monthly basis. After doing EDA and fitting a linear model, we concluded that neither the vaccination rate and mortality nor the second dose rate and mortality followed a linear relationship. After that, we discussed possible problems in the data and analysis and listed some possible improvements.
